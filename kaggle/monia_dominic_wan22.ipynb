# %% [markdown]
# # MonIA — Dominic Wan 2.2 sur Kaggle (0 €)\nCe notebook utilise le GPU gratuit Kaggle et le modèle Wan2.2-TI2V-5B avec offload mémoire.

# %%
# !nvidia-smi\n!pip install -q -U diffusers transformers accelerate safetensors imageio imageio-ffmpeg ftfy\n!apt-get -qq update && apt-get -qq install -y ffmpeg\n

# %%
# !git clone -q https://github.com/vartcom38-collab/marion-lucas-game.git /kaggle/working/marion-lucas-game || true\n%cd /kaggle/working/marion-lucas-game\n!git pull -q\n

# %%
# !python scripts/monia_kaggle_wan22.py --shot dominic-seated-thought\n

# %% [markdown]
# La vidéo validée se trouve dans `/kaggle/working/monia-dominic/`. Si le contrôle d’identité échoue, le notebook s’arrête et ne valide pas le clip.
